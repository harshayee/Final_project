# %%
df=pd.read_csv("sample30.csv")

# %%
import random

# Assuming df is your DataFrame containing the data
# Create a copy of the DataFrame to avoid modifying the original DataFrame
df_copy = df.copy()

# Initialize an empty dictionary to store the mapping between users and their unique IDs
user_ids = {}

# Generate unique 5-digit random numbers for each user
for index, row in df_copy.iterrows():
    username = row['reviews_username']
    if username not in user_ids:
        user_ids[username] = random.randint(10000, 99999)

df_copy['customer_id'] = df_copy['reviews_username'].map(user_ids)

# %%
df_copy.head(10)
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
# 5  AV16khLE-jtxr-f38VFn              K-Y
# 6  AV16khLE-jtxr-f38VFn              K-Y
# 7  AV16khLE-jtxr-f38VFn              K-Y
# 8  AV16khLE-jtxr-f38VFn              K-Y
# 9  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 5  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 6  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 7  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# ...

# %%
id_column = df['id']

print(id_column)
# Out:
# 0        AV13O1A8GV-KLJ3akUyj
# 1        AV14LG0R-jtxr-f38QfS
# 2        AV14LG0R-jtxr-f38QfS
# 3        AV16khLE-jtxr-f38VFn
# 4        AV16khLE-jtxr-f38VFn
#                  ...
# 29995    AVpfW8y_LJeJML437ySW
# 29996    AVpfW8y_LJeJML437ySW
# 29997    AVpfW8y_LJeJML437ySW
# 29998    AVpfW8y_LJeJML437ySW
# 29999    AVpfW8y_LJeJML437ySW
# Name: id, Length: 30000, dtype: object

# %%
import re

# %%
# df_copy['product_id'] = df['id'].str.extract(r'(\d+)')
# df_copy['product_id'] = df['id'].str.extract(r'(\d+)')
df['product_id'] = df['id'].apply(lambda x: ''.join(re.findall(r'\d+', x)))

df_copy.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...
#
#                          manufacturer  \
# 0  Universal Music Group / Cash Money
# 1                            Lundberg
# 2                            Lundberg
# 3                                 K-Y
# 4                                 K-Y
#
#                                          name              reviews_date  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  2012-11-30T06:21:45.000Z
# ...

# %%
product_ids = {}

# Generate unique 5-digit random numbers for each user
for index, row in df_copy.iterrows():
    productname = row['name']
    if productname not in product_ids:
        product_ids[productname] = random.randint(100000, 999999)

df_copy['product_id'] = df_copy['name'].map(product_ids)
df_copy.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...
#
#                          manufacturer  \
# 0  Universal Music Group / Cash Money
# 1                            Lundberg
# 2                            Lundberg
# 3                                 K-Y
# 4                                 K-Y
#
#                                          name              reviews_date  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  2012-11-30T06:21:45.000Z
# ...

# %%
info= df_copy[['product_id','name','brand','categories','manufacturer']]

# %%
info.head()
# Out:
#    product_id                                        name            brand  \
# 0      380442   Pink Friday: Roman Reloaded Re-Up (w/dvd)  Universal Music
# 1      671581  Lundberg Organic Cinnamon Toast Rice Cakes         Lundberg
# 2      671581  Lundberg Organic Cinnamon Toast Rice Cakes         Lundberg
# 3      887382            K-Y Love Sensuality Pleasure Gel              K-Y
# 4      887382            K-Y Love Sensuality Pleasure Gel              K-Y
#
#                                           categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...
#
#                          manufacturer
# 0  Universal Music Group / Cash Money
# 1                            Lundberg
# 2                            Lundberg
# ...

# %%
print(info.isnull().sum())
# Out:
# product_id    0
# name          0
# brand         0
# categories    0
# dtype: int64

# %%
info.drop(columns=['manufacturer'], inplace=True)
# Out:
# <ipython-input-27-b6137ba0e186>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info.drop(columns=['manufacturer'], inplace=True)

# %%
info.head()
# Out:
#    product_id                                        name            brand  \
# 0      380442   Pink Friday: Roman Reloaded Re-Up (w/dvd)  Universal Music
# 1      671581  Lundberg Organic Cinnamon Toast Rice Cakes         Lundberg
# 2      671581  Lundberg Organic Cinnamon Toast Rice Cakes         Lundberg
# 3      887382            K-Y Love Sensuality Pleasure Gel              K-Y
# 4      887382            K-Y Love Sensuality Pleasure Gel              K-Y
#
#                                           categories
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...

# %%
info.count()
# Out:
# product_id    30000
# name          30000
# brand         30000
# categories    30000
# dtype: int64

# %%
df_subset = info.head(10000)
df_subset.to_csv('product_info.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
ratings=df_copy[['product_id','customer_id','reviews_rating']]
ratings.head()
# Out:
#    product_id  customer_id  reviews_rating
# 0      380442        62718               5
# 1      671581        73662               5
# 2      671581        73662               5
# 3      887382        27649               1
# 4      887382        24404               1

# %%
print(ratings.isnull().sum())
# Out:
# product_id        0
# customer_id       0
# reviews_rating    0
# dtype: int64

# %%
df_subset2 = info.head(10000)
df_subset2.to_csv('product_ratings.csv', index=False)
